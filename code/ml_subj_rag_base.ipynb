# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install faiss-cpu pdfplumber docling -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 92.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 136.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.9/276.9 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 111.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 109.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 132.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 91.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 66.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 48.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.0/345.0 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 26.5 MB/s eta 0:00:00
#   Building wheel for pylatexenc (setup.py) ... done

# %%
import os
import json
import faiss
import numpy as np
import pdfplumber
from typing import List, Dict
from docx import Document
from sentence_transformers import SentenceTransformer
from docling.document_converter import DocumentConverter
from docling_core.types.doc import DocItemLabel

# %%
BATCH_SIZE = 4
MAX_CHUNK_SIZE = 1000
DOC_FILEPATH = '/content/drive/MyDrive/hust_docs'
OUT_DIR = '/content/drive/MyDrive/rag'
EMBED_MODEL = 'BAAI/bge-m3'

# %%
def normalize_token(w: str) -> str:
    return ''.join(c for c in w.lower() if c.isalnum())


def pdf_to_dict(pdf_path: str) -> set:
    words = set()
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text() or ""
            for w in text.split():
                w = normalize_token(w)
                if 2 <= len(w) <= 8:
                    words.add(w)
    return words


def docx_to_dict(docx_path: str) -> set:
    words = set()
    doc = Document(docx_path)
    for para in doc.paragraphs:
        text = para.text or ""
        for w in text.split():
            w = normalize_token(w)
            if 2 <= len(w) <= 8:
                words.add(w)
    return words


def repair_raw(line: str, dictionary: set) -> str:
    tokens = line.split(' ')
    repaired = []
    i = 0

    while i < len(tokens):
        t0 = normalize_token(tokens[i])

        if i + 3 < len(tokens):
            merged4 = normalize_token(tokens[i] + tokens[i + 1] + tokens[i + 2] + tokens[i + 3])
            if merged4 in dictionary:
                repaired.append(tokens[i] + tokens[i + 1] + tokens[i + 2] + tokens[i + 3])
                i += 4
                continue

        if i + 2 < len(tokens):
            merged3 = normalize_token(tokens[i] + tokens[i + 1] + tokens[i + 2])
            if merged3 in dictionary:
                repaired.append(tokens[i] + tokens[i + 1] + tokens[i + 2])
                i += 3
                continue

        if i + 1 < len(tokens):
            merged2 = normalize_token(tokens[i] + tokens[i + 1])
            if merged2 in dictionary:
                repaired.append(tokens[i] + tokens[i + 1])
                i += 2
                continue

        repaired.append(tokens[i])
        i += 1

    return " ".join(repaired)


def repair(text: str, dictionary: set) -> str:
    out = []
    for line in text.splitlines(keepends=True):
        newline = "\n" if line.endswith("\n") else ""
        content = line.rstrip("\n")
        out.append(repair_raw(content, dictionary) + newline)
    return "".join(out)

def iter_blocks(document, max_chunk_size: int):
    blocks = []

    current_section = "ROOT"
    current_content = []
    current_length = 0

    def flush():
        nonlocal current_content, current_length
        if current_content:
            blocks.append({
                "type": "section",
                "section": current_section,
                "content": "\n\n".join(current_content)
            })
            current_content = []
            current_length = 0

    for item, stack in document.iterate_items():
        label = item.label

        if label in (DocItemLabel.TITLE, DocItemLabel.SECTION_HEADER):
            text = item.text.strip()
            if text and stack <= 0:
                flush()
                current_section = text
                current_content = [text]
                current_length = len(text)
            continue

        if label in (DocItemLabel.PARAGRAPH, DocItemLabel.TEXT, DocItemLabel.LIST_ITEM):
            text = item.text.strip()
            if not text:
                continue

            text_len = len(text) + (2 if current_content else 0)

            if current_length + text_len > max_chunk_size:
                flush()

            current_content.append(text)
            current_length += text_len
            continue

        if label == DocItemLabel.TABLE:
            table_md = item.export_to_markdown(document)
            flush()
            blocks.append({
                "type": "table",
                "section": current_section,
                "content": table_md
            })
            continue

    flush()
    return blocks

def convert_file(file_path, max_chunk_size = MAX_CHUNK_SIZE) -> List[Dict]:
    try:
        ext = os.path.splitext(file_path)[1].lower()
        converter = DocumentConverter()

        print(f"Converting: {file_path}")
        result = converter.convert(file_path)

        if ext == ".pdf":
            dictionary = pdf_to_dict(file_path)
        elif ext == ".docx":
            dictionary = docx_to_dict(file_path)
        else:
            return []

        blocks = iter_blocks(result.document, max_chunk_size)
        docs = []

        for b in blocks:
            text = repair(b["content"], dictionary)
            metadata = {
                "source": os.path.basename(file_path),
                "section": repair(b["section"], dictionary),
                "type": b["type"]
            }

            docs.append({
                "text": text,
                "metadata": metadata
            })

        return docs

    except Exception as e:
        print(f"[ERROR] Failed processing: {file_path}")
        print(str(e))
        return []


def build_index(all_docs: List[Dict], embedder) -> faiss.Index:
    dim = embedder.get_sentence_embedding_dimension()
    index = faiss.IndexFlatIP(dim)

    texts = [d["text"] for d in all_docs]

    for i in range(0, len(texts), BATCH_SIZE):
        batch = texts[i:i + BATCH_SIZE]
        emb = embedder.encode(
            batch,
            normalize_embeddings=True,
            show_progress_bar=False
        )
        index.add(np.asarray(emb, dtype="float32"))
        if i % (BATCH_SIZE * 10) == 0:
            print(f"Indexed {min(i + BATCH_SIZE, len(texts))}/{len(texts)}")

    return index

# %%
docs: List[Dict] = []

for fn in sorted(os.listdir(DOC_FILEPATH)):
    if fn.lower().endswith((".pdf", ".docx")):
        docs.extend(convert_file(os.path.join(DOC_FILEPATH, fn), MAX_CHUNK_SIZE))

print(f"Total blocks: {len(docs)}")

embedder = SentenceTransformer(EMBED_MODEL)
index = build_index(docs, embedder)

os.makedirs(OUT_DIR, exist_ok=True)
faiss.write_index(index, os.path.join(OUT_DIR, "rag.index"))

with open(os.path.join(OUT_DIR, "metadata.json"), "w", encoding="utf-8") as f:
    json.dump(docs, f, ensure_ascii=False, indent=2)

print("Index and metadata saved")
# Out:
# Converting: /content/drive/MyDrive/hust_docs/01_1%202015%20TT%20Lien%20tich_QD%20danh%20gia%20QP-AN.pdf
# [INFO] 2026-01-03 08:20:15,093 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:15,108 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:15,117 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:16,509 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-01-03 08:20:16,980 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:16,984 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:18,007 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:18,015 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:18,018 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/cls/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:18,924 [RapidOCR] download_file.py:82: Download size: 0.56MB
# [INFO] 2026-01-03 08:20:18,965 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:18,973 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:19,231 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:19,234 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:19,239 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/rec/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:20:19,964 [RapidOCR] download_file.py:82: Download size: 25.67MB
# [INFO] 2026-01-03 08:20:20,669 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:20:20,676 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Converting: /content/drive/MyDrive/hust_docs/01_3%20HD%20hoc%20chuyen%20tiep%20ky%20su%20180%20TC_Final.pdf
# [INFO] 2026-01-03 08:20:35,589 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:35,590 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:35,631 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:35,632 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:35,866 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:35,867 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:35,871 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:35,872 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:35,958 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:35,959 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:36,046 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:20:36,047 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/02_%20Th%E1%BB%A7%20th%E1%BB%A5c_Bi%E1%BB%83u%20m%E1%BA%ABu%20(k%C3%A8m%20Quy%20ch%E1%BA%BF%20%C4%90T).pdf
# [INFO] 2026-01-03 08:20:39,153 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:39,155 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:39,199 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:39,200 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:39,430 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:39,431 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:39,436 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:39,436 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:39,521 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:39,521 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:39,595 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:20:39,596 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/02_gioi%20thieu%20NoteBookLM.pdf
# [INFO] 2026-01-03 08:20:46,996 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:46,997 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:47,046 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:47,047 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:47,270 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:47,271 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:47,275 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:47,276 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:47,365 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:47,366 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:47,440 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:20:47,441 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/03_1%20HUST's%20ACADEMIC%20REGULATIONS-2025_Final.pdf
# [INFO] 2026-01-03 08:20:58,325 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:58,326 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:58,368 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:58,369 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:20:58,599 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:58,600 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:58,605 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:58,606 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:20:58,691 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:20:58,692 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:20:58,767 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:20:58,768 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# [INFO] 2026-01-03 08:21:23,486 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:21:23,488 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:21:23,565 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:21:23,566 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:21:23,937 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:21:23,938 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:21:23,943 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:21:23,944 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:21:24,087 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:21:24,088 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:21:24,216 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:21:24,217 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/11-Mẫu CNHB KKHT 2025.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/2-Giay chung nhan sinh vien 2025.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/23_%20%C4%90%C6%A1n%20xin%20c%E1%BA%A5p%20b%E1%BA%A3n%20sao%20v%C4%83n%20b%E1%BA%B1ng.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/23_%20Don%20xin%20cap%20ban%20sao%20bang%20TN.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/3-Giay gioi thieu sinh vien 2025.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/Diem%20moi%20cua%20QCDT%202025.pdf
# [INFO] 2026-01-03 08:21:59,000 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:21:59,001 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:21:59,043 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:21:59,044 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:21:59,271 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:21:59,272 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:21:59,277 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:21:59,277 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:21:59,364 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:21:59,365 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:21:59,439 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:21:59,440 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/ERR1zxfXQIFOgaAM4mULdi8B_M3a5qSmf1g04v1L5Zyabg.docx
# ERROR:docling.datamodel.document:Input document ERR1zxfXQIFOgaAM4mULdi8B_M3a5qSmf1g04v1L5Zyabg.docx with format None does not match any allowed format: (dict_keys([<InputFormat.DOCX: 'docx'>, <InputFormat.PPTX: 'pptx'>, <InputFormat.HTML: 'html'>, <InputFormat.IMAGE: 'image'>, <InputFormat.PDF: 'pdf'>, <InputFormat.ASCIIDOC: 'asciidoc'>, <InputFormat.MD: 'md'>, <InputFormat.CSV: 'csv'>, <InputFormat.XLSX: 'xlsx'>, <InputFormat.XML_USPTO: 'xml_uspto'>, <InputFormat.XML_JATS: 'xml_jats'>, <InputFormat.METS_GBS: 'mets_gbs'>, <InputFormat.JSON_DOCLING: 'json_docling'>, <InputFormat.AUDIO: 'audio'>, <InputFormat.VTT: 'vtt'>]))
# [ERROR] Failed processing: /content/drive/MyDrive/hust_docs/ERR1zxfXQIFOgaAM4mULdi8B_M3a5qSmf1g04v1L5Zyabg.docx
# File format not allowed: ERR1zxfXQIFOgaAM4mULdi8B_M3a5qSmf1g04v1L5Zyabg.docx
# Converting: /content/drive/MyDrive/hust_docs/ERczoBK8xr9PutLrx9PkEAABP7iFQRhguBqzkg1jQcFJWQ.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/HD%20chuyen%20truong%20SV%20hoc%20nuoc%20ngoai%20ve%20VN.pdf
# [INFO] 2026-01-03 08:22:09,141 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:09,142 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:09,186 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:09,187 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:09,414 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:09,415 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:09,420 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:09,420 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:09,521 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:09,521 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:09,596 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:09,597 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/KH%20nam%20hoc%202025-2026_CN_KS.pdf
# [INFO] 2026-01-03 08:22:13,160 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:13,161 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:13,202 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:13,203 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:13,436 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:13,437 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:13,442 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:13,443 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:13,542 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:13,543 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:13,621 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:13,622 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/Khung%20KH%202024-2025_CN_KS.pdf
# [INFO] 2026-01-03 08:22:17,604 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:17,605 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:17,680 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:17,681 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:18,068 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:18,069 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:18,075 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:18,077 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:18,221 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:18,222 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:18,347 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:18,349 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/Khung%20Ke%20hoach%20thoi%20gian%20nam%20hco%202023-2024.pdf
# [INFO] 2026-01-03 08:22:21,239 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:21,240 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:21,281 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:21,282 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:21,513 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:21,514 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:21,518 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:21,520 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:21,610 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:21,611 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:21,688 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:21,689 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/Khung%20ke%CC%82%CC%81%20hoa%CC%A3ch%20th%E1%BB%9Di%20gian%20n%C4%83m%20h%E1%BB%8Dc%202022-2023%20-%2011092022.pdf
# [INFO] 2026-01-03 08:22:30,052 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:30,053 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:30,130 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:30,130 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:30,481 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:30,483 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:30,490 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:30,491 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:30,640 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:30,642 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:30,770 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:30,771 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/Khung-DGRL-2020-2021.pdf
# [INFO] 2026-01-03 08:22:37,758 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:37,759 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:37,803 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:37,804 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:38,030 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:38,031 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:38,036 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:38,037 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:38,126 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:38,126 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:38,201 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:38,202 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/M%E1%BA%ABu%20%C4%90ATN_2019_version%201_1.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/M%E1%BA%ABu%20%C4%91%C6%A1n.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/M%E1%BA%ABu%20Gi%E1%BA%A5y%20x%C3%A1c%20nh%E1%BA%ADn.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/Mẫu Giấy xác nhận.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/Mẫu đơn đk HB TĐN.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/Mẫu đơn.docx
# WARNING:docling.backend.msword_backend:Found DrawingML elements in document, but no DOCX to PDF converters. If you want these exported, make sure you have LibreOffice binary in PATH or specify its path with DOCLING_LIBREOFFICE_CMD.
# Converting: /content/drive/MyDrive/hust_docs/QCDT-2023-upload.pdf
# [INFO] 2026-01-03 08:22:52,483 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:52,484 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:52,526 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:52,527 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:22:52,750 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:52,751 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:52,756 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:52,756 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:22:52,845 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:22:52,846 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:22:52,923 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:22:52,924 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QCDT_2025_5445_QD-DHBK.pdf
# [INFO] 2026-01-03 08:23:17,747 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:17,748 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:17,794 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:23:17,794 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:23:18,713 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:18,714 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:18,718 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:23:18,719 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:23:18,808 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:18,808 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:18,884 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:23:18,885 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QD%20HOC%20PHI%20-%202025-2026-final.pdf
# [INFO] 2026-01-03 08:23:43,336 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:43,337 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:43,378 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:23:43,379 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:23:43,615 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:43,616 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:43,622 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:23:43,624 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:23:43,712 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:43,713 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:43,790 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:23:43,791 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QD%20NN%20DHCQ-2020-2021-1501.pdf
# [INFO] 2026-01-03 08:23:53,173 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:53,174 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:53,217 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:23:53,218 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:23:53,451 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:53,452 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:53,457 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:23:53,458 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:23:53,543 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:23:53,544 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:23:53,619 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:23:53,620 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QD%20ban%20hanh%20QD%20chuyen%20doi%20hoc%20phan%20tuong%20duong.pdf
# [INFO] 2026-01-03 08:24:50,273 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:24:50,274 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:24:50,317 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:24:50,318 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:24:50,564 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:24:50,565 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:24:50,569 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:24:50,570 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:24:50,666 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:24:50,667 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:24:50,749 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:24:50,750 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QD%20ban%20hanh%20QD%20to%20chuc%20day%20hoc%20tren%20nen%20tang%20CN%20ket%20noi%20-%20truc%20tuyen.pdf
# [INFO] 2026-01-03 08:25:05,602 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:05,603 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:05,654 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:25:05,655 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:25:05,906 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:05,908 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:05,913 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:25:05,914 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:25:06,014 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:06,015 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:06,101 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:25:06,103 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QD%20ban%20hanh%20QD%20to%20chuc%20thi%20Truc%20tuyen.pdf
# [INFO] 2026-01-03 08:25:21,832 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:21,833 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:21,879 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:25:21,880 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:25:22,121 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:22,123 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:22,129 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:25:22,130 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:25:22,240 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:22,240 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:22,320 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:25:22,321 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Converting: /content/drive/MyDrive/hust_docs/QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [INFO] 2026-01-03 08:25:40,131 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:40,134 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:40,207 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:25:40,209 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-03 08:25:40,600 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:40,601 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:40,605 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:25:40,606 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-03 08:25:40,694 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-03 08:25:40,694 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-03 08:25:40,772 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-03 08:25:40,773 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# Total blocks: 681
# Indexed 4/681
# Indexed 44/681
# Indexed 84/681
# Indexed 124/681
# Indexed 164/681
# Indexed 204/681
# Indexed 244/681
# Indexed 284/681
# Indexed 324/681
# Indexed 364/681
# Indexed 404/681
# Indexed 444/681
# Indexed 484/681
# Indexed 524/681
# Indexed 564/681
# Indexed 604/681
# Indexed 644/681
# Indexed 681/681
# Index and metadata saved

# %%
def retrieve(query, embedder, index, all_docs, top_k=5):
    query_emb = embedder.encode(
        [query],
        normalize_embeddings=True
    )

    scores, indices = index.search(
        np.array(query_emb, dtype="float32"),
        top_k
    )

    results = []
    for score, idx in zip(scores[0], indices[0]):
        if idx == -1:
            continue
        results.append({
            "score": float(score),
            "text": all_docs[idx]["text"],
            "metadata": all_docs[idx]["metadata"]
        })

    return results

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install faiss-cpu -q

# %%
import json
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

index = faiss.read_index(f"{OUT_DIR}/rag.index")

with open(f"{OUT_DIR}/metadata.json", "r", encoding="utf-8") as f:
    docs = json.load(f)

print("Index size :", index.ntotal)
print("Docs count :", len(docs))

assert index.ntotal == len(docs)

embedder = SentenceTransformer(EMBED_MODEL)
# Out:
# Index size : 681
# Docs count : 681

# %%
query = "Cần chứng chỉ tiếng anh gì để được miễn học phần tiếng anh"

results = retrieve(
    query=query,
    embedder=embedder,
    index=index,
    all_docs=docs,
    top_k=40
)

for i, r in enumerate(results, 1):
    print(f"\n--- Result {i} ---")
    print(f"Score   : {r['score']:.4f}")
    print(f"Section : {r['metadata']['section']}")
    print(f"Type    : {r['metadata']['type']}")
    print(f"Source  : {r['metadata']['source']}")
    print(r["text"])
# Out:
# --- Result 1 ---
# Score   : 0.7023
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 6.1 Danh mục các học phần tiếng Anh yêu cầu
#
# |TT |Mã học phần| Tên học phần            |Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được|
# |------|---------------|------------------------------|--------------|---------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|
# |      |               |                              |              |                           | [1]                                                  | [2]                                                  | [3]                                                  | [4]                                                  | [5]                                                  |
# | 1  |CLE1311       | Elementary English 1       |3(3-1-0-6) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    | M                                                    |
# | 2  |CLE1312       | Elementary English 2       |3(3-1-0-6) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    | M                                                    |
# | 3  |CLE2311     |Pre - Intermediate English 1 |3(3-1-0-6) |Không                   | H                                                    | H                                                    | M                                                    | M                                                    | M                                                    |
# | 4  |CLE2312     |Pre - Intermediate English 2 |3(3-1-0-6) |Không                   | H                                                    | H                                                    | M                                                    | M                                                    | M                                                    |
# | 5  |CLE3401       | Intermediate English 1     |4(4-0-0-8) |Không                     | H                                                    | H                                                    | H                                                    | M                                                    | M                                                    |
# | 6  |CLE3402       | Intermediate English 2     |4(4-0-0-8) |Không                     | H                                                    | H                                                    | H                                                    | M                                                    | M                                                    |
# | 7  |CLE4401     |IELTS1 Preparation         |4(4-0-0-8) |Không                     | H                                                    | H                                                    | H                                                    | M                                                    | M                                                    |
# | 8  |QT1331      |Tiếng Anh 3 (B2.1)      |3(2-2-0-6) |Có (3 TC)              | H                                                    | H                                                    | H                                                    | H                                                    | M                                                    |
# | 9  |QT1341      |Tiếng Anh 4 (B2.2)      |3(2-2-0-6) |Có (3 TC)              | H                                                    | H                                                    | H                                                    | H                                                    | M                                                    |
#
# --- Result 2 ---
# Score   : 0.6859
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 3.1 Danh mục các học phần tiếng Anh yêu cầu
#
# |TT |Mã học phần| Tên học phần |Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn/cần học| Học phần được miễn/cần học| Học phần được miễn/cần học| Học phần được miễn/cần học| Học phần được miễn/cần học| Học phần được miễn/cần học|
# |------|---------------|-------------------|--------------|---------------------------|------------------------------|------------------------------|------------------------------|------------------------------|------------------------------|------------------------------|
# |TT |Mã học phần| Tên học phần |Thời lượng| Tính tín chỉ trong CTĐT| [1]                          | [2]                          | [3]                          | [4]                          | [5]                          | [6]                          |
# | 1  |FL1131      |Tiếng Anh cơ sở 1 |4(2-4-0-8) |Không                   | H                            | M                            | M                            | M                            | M                            | M                            |
# | 2  |FL1132      |Tiếng Anh cơ sở 2 |4(2-4-0-8) |Có (4 TC)              | H                            | H                            | M                            | M                            | M                            | M                            |
# | 3  |FL1133      |Tiếng Anh cơ sở 3 |4(2-4-0-8) |Có (4 TC)              | H                            | H                            | H                            | M                            | M                            | M                            |
# | 4  |FL1134      |Tiếng Anh cơ sở 4 |4(2-4-0-8) |Không                   | H                            | H                            | H                            | H                            | M                            | M                            |
# | 5  |FL1135      |Tiếng Anh cơ sở 5 |4(2-4-0-8) |Không                   | H                            | H                            | H                            | H                            | H                            | M                            |
#
# --- Result 3 ---
# Score   : 0.6823
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 5.1 Danh mục các học phần tiếng Anh yêu cầu
#
# |TT |Mã học phần| Tên học phần             |Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được|
# |------|---------------|-------------------------------|--------------|---------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|
# |TT |Mã học phần| Tên học phần             |Thời lượng| Tính tín chỉ trong CTĐT| [1]                                                  | [2]                                                  | [3]                                                  | [4]                                                  |
# | 1  |FL1141        | Practical grammar for writing| 3(1-4-0-6)| Không                  | H                                                    | M                                                    | M                                                    | M                                                    |
# | 2  |FL1142        | Communication skills 1      |3(1-4-0-6) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    |
# | 3  |FL1143      |Working with text 1         |3(1-4-0-6) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    |
# | 4  |FL1144        | Listening                   |3(2-2-0-6) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    |
# | 5  |FL1145      |Speaking                    |2(1-3-0-4) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    |
# | 6  |FL1146      |Reading                     |2(1-2-0-4) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    |
# | 7  |FL1147      |Writing                     |3(2-2-0-6) |Không                     | H                                                    | M                                                    | M                                                    | M                                                    |
# | 8  |FL1148        | Foundation Writing       |2(1-2-0-4) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# | 9  |FL1149        | Communication Skills 2      |3(2-2-0-6) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# |10 |FL1150    |Working with text 2         |2(1-2-0-4) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# |11 |FL1120    |IELTS Listening 1           |2(2-1-0-4) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# |12 |FL1121    |IELTS Speaking 1            |1(1-1-0-4) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# |13 |FL1122    |IELTS Reading 1             |1(1-1-0-4) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# |14 |FL1123    |IELTS Writing 1             |2(2-1-0-4) |Không                     | M                                                    | H                                                    | M                                                    | M                                                    |
# |15 |FL1124    |IELTS Listening 2           |2(2-1-0-4) |Có                        | H                                                    | H                                                    | H                                                    | M                                                    |
# |16 |FL1125    |IELTS Speaking 2            |1(1-1-0-4) |Có                        | H                                                    | H                                                    | H                                                    | M                                                    |
# |17 |FL1126    |IELTS Reading 2             |1(1-1-0-4) |Có                        | H                                                    | H                                                    | H                                                    | M                                                    |
#
# --- Result 4 ---
# Score   : 0.6740
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Trong quá trình học tập, nếu sinh viên đạt được chứng chỉ ngoại ngữ theo quy định sẽ được xét miễn các học phần NNCB tương ứng với trình độ đạt được. Kết quả miễn học được ghi bằng ký hiệu 'R' trong dữ liệu học tập và có giá trị toàn khóa kể từ ngày nhập điểm R.
#
# Chứng chỉ ngoại ngữ để xét miễn học phần NNCB phải còn hạn theo quy định tính tới thời điểm nộp đơn xét miễn. Danh mục chứng chỉ và học phần NNCB được miễn tương ứng được quy định tại các Phụ lục tương ứng kèm theo Quy định này.
#
# Các chứng chỉ ngoại ngữ quốc gia, quốc tế phải được thẩm định nguồn gốc và cập nhật mức điểm lên hệ thống phần mềm quản lý đào tạo trước thời điểm nộp đơn đề nghị xét miễn học phần NNCB.
#
# Thời gian tiếp nhận đơn đề nghị xét miễn học phần NNCB muộn nhất là 2 tuần trước khi bắt đầu học kỳ theo Khung kế hoạch năm học.
#
# --- Result 5 ---
# Score   : 0.6697
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Ghi chú: Được xếp học tương ứng với kết quả phân loại tiếng Anh đầu vào;
#
# [1]: Cần học toàn bộ các học phần;
#
# [2]: Đạt trình độ Bậc 1.2 trở lên hoặc tương đương;
#
# [3]: Đạt trình độ Bậc 2.1 trở lên hoặc tương đương;
#
# [4]: Đạt trình độ Bậc 2.2 trở lên hoặc tương đương;
#
# [5]: Đạt trình độ Bậc 2.3 trở lên hoặc tương đương;
#
# [6]: Đạt trình độ Bậc 3.1 trở lên hoặc tương đương;
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# Bậc trình độ dựa trên Khung năng lực ngoại ngữ 6 bậc của Việt Nam có trong Phụ lục 2 của quy định này.
#
# --- Result 6 ---
# Score   : 0.6627
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ Goethe-Zertifikat A1 hoặc tương đương
#
# [3]: Đạt trình độ Goethe-Zertifikat B1 hoặc tương đương
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# (*)Học phần QT1524 Tiếng Đức 5: chỉ dành cho các sinh viên học chuyển tiếp sang Đức theo chương trình Kỹ thuật Điện tử- Viễn thông, hợp tác với ĐH Leibniz Hannover.
#
# (*)Học phần QT1524 Tiếng Đức 5, QT1528 Tiếng Đức 6, QT1529 Tiếng Đức 7: chỉ dành cho các sinh viên học chuyển tiếp sang Đức theo chương trình Kỹ thuật Cơ điện tử, hợp tác với ĐH Leibniz Hannover.
#
# [2]: Đạt trình độ Goethe-Zertifikat A2 hoặc tương đương
#
# [4]: Đạt trình độ Goethe-Zertifikat B2 hoặc tương đương
#
# --- Result 7 ---
# Score   : 0.6500
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Được xếp học tương ứng với kết quả phân loại tiếng Anh đầu vào;
#
# [2]: Đạt trình độ Bậc 1.2 trở lên hoặc tương đương;
#
# [3]: Đạt trình độ Bậc 2.1 trở lên hoặc tương đương;
#
# [4]: Đạt trình độ Bậc 2.2 trở lên hoặc tương đương;
#
# [5]: Đạt trình độ Bậc 2.3 trở lên hoặc tương đương;
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# Bậc trình độ dựa trên Khung năng lực ngoại ngữ 6 bậc của Việt Nam có trong Phụ lục 2 của quy định này.
#
# --- Result 8 ---
# Score   : 0.6446
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ IELTS dưới 3.0 hoặc tương đương;
#
# [3]: Đạt trình độ IELTS 4.5-5.0 hoặc tương đương;
#
# [2]: Đạt trình độ IELTS 3.0-4.0 hoặc tương đương;
#
# [4]: Đạt trình độ IELTS từ 5.5 hoặc tương đương.
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# --- Result 9 ---
# Score   : 0.6426
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 7.1 Danh mục các học phần tiếng Pháp yêu cầu đối với chương trình đào tạo PFIEV
#
# |TT |Mã học phần| Tên học phần      |Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được|
# |------|---------------|------------------------|--------------|---------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|
# |TT |Mã học phần| Tên học phần      |Thời lượng| Tính tín chỉ trong CTĐT| [1]                                                  | [2]                                                  | [3]                                                  |
# | 1  |FL1401 (*)  |Tiếng Pháp KSCLC 1 (*)|3(3-2-0-6) |Có                       | M                                                    | M                                                    | M                                                    |
# | 2  |FL1802      |Tiếng Pháp PFIEV 2   |3(1-4-0-6) |Có                        | M                                                    | M                                                    | M                                                    |
# | 3  |FL1803      |Tiếng Pháp PFIEV 3   |3(1-4-0-6) |Không                     | H                                                    | M                                                    | M                                                    |
# | 4  |FL1804      |Tiếng Pháp PFIEV 4   |3(1-4-0-6) |Không                     | H                                                    | M                                                    | M                                                    |
# | 5  |FL1805      |Tiếng Pháp PFIEV 5   |3(1-4-0-6) |Không                     | H                                                    | H                                                    | M                                                    |
# | 6  |FL1806      |Tiếng Pháp PFIEV 6   |3(3-1-0-6) |Không                     | H                                                    | H                                                    | M                                                    |
#
# --- Result 10 ---
# Score   : 0.6397
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Học kỳ thứ 3: dành cho sinh viên để tự đăng ký học lại các học phần ngoại ngữ không đạt ở 2 học kỳ đầu (nếu có) và chủ động thi chứng chỉ ngoại ngữ.
#
# Từ kỳ thứ 4 trở đi: Ban Đào tạo sẽ thực hiện việc đăng ký bắt buộc các học phần ngoại ngữ đối với các sinh viên không đạt chuẩn ngoại ngữ theo số lượng tín chỉ tích lũy.
#
# Trong quá trình học tập, nếu sinh viên đạt được chứng chỉ ngoại ngữ theo quy định sẽ được xét miễn các học phần ngoại ngữ tương ứng với trình độ đạt được. Các học phần được miễn sẽ được ghi điểm R trong bảng điểm.
#
# Chứng chỉ ngoại ngữ để xét miễn học phần phải còn hạn theo quy định tính tới thời điểm nộp đơn xét miễn. Danh sách chứng chỉ và các học phần được miễn được ghi trong các phụ lục tương ứng kèm theo Quy định này.
#
# Toàn bộ các chứng chỉ ngoại ngữ quốc gia, quốc tế phải được thẩm định nguồn gốc và cập nhật mức điểm lên hệ thống phần mềm quản lý đào tạo trước thời điểm nộp đơn đề nghị xét miễn học phần ngoại ngữ.
#
# --- Result 11 ---
# Score   : 0.6384
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Nhóm 1
#
# :Không tham gia đánh giá phân loại tiếng Anh đầu vào hoặc đạt trình độ từ Bậc 2.2 trở xuống;
#
# Nhóm 2: Đạt trình độ Bậc 2.3 đến Bậc 3.1
#
# M: Được miễn học (ghi điểm R)
#
# Nhóm 3: Đạt trình độ Bậc 3.2
#
# Kỳ
#
# 1: Được xếp học ở kỳ 1
#
# Nhóm 4: Đạt trình độ Bậc 4 trở lên
#
# Kỳ
#
# 2: Được xếp học ở kỳ 2
#
# ĐK:
#
# Sinh viên tự đăng ký học song hành với các học phần của CTĐT tại kỳ 3 nếu chưa được miễn.
#
# Đối với các chứng chỉ APTIS ESOL, Cambridge Assessment English, PEIC: Sinh viên đạt chứng chỉ A2 sẽ thuộc Nhóm 2; đạt chứng chỉ B1 sẽ thuộc Nhóm 3.
#
# Bậc trình độ dựa trên quy định tại Bảng 2.1 của Phụ lục II.
#
# (Bảng 4.2 này không áp dụng với CTĐT hợp tác với Đại học TROY, Hoa Kỳ)
#
# --- Result 12 ---
# Score   : 0.6354
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ IELTS từ 3.0 trở xuống hoặc tương đương;
#
# [3]: Đạt trình độ IELTS 4.0 hoặc tương đương;
#
# [5]: Đạt trình độ IELTS quốc tế từ 5.5 hoặc tương đương.
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# [2]: Đạt trình độ IELTS 3.5 hoặc tương đương;
#
# [4]: Đạt trình độ IELTS từ 4.5-5.0 hoặc tương đương;
#
# --- Result 13 ---
# Score   : 0.6342
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ DELF A1 hoặc tương đương;
#
# [2]: Đạt trình độ DELF A2 hoặc tương đương;
#
# [3]: Đạt trình độ DELF B1 hoặc tương đương;
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# (*):từ khóa K69 sẽ đổi mã và tên học phần thành: FL1801 Tiếng Pháp PFIEV 1.
#
# (**):từ khóa K69 sẽ đổi mã và tên học phần thành: FL1802 Tiếng Pháp PFIEV 2.
#
# --- Result 14 ---
# Score   : 0.6325
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 7.2 Danh mục các học phần tiếng Pháp yêu cầu đối với chương trình Công nghệ thông tin Việt-Pháp
#
# |TT |Mã học phần| Tên học phần    |Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được|
# |------|---------------|----------------------|--------------|---------------------------|------------------------------------------------------|------------------------------------------------------|------------------------------------------------------|
# |TT |Mã học phần| Tên học phần    |Thời lượng| Tính tín chỉ trong CTĐT| [1]                                                  | [2]                                                  | [3]                                                  |
# | 1  |FL1601 (*)  |Tiếng Pháp VP 1 (*)|3(1-4-0-6) |Không                     | M                                                    | M                                                    | M                                                    |
# | 2  |FL1602 (**) |Tiếng Pháp VP 2 (**)|2(1-2-0-4) |Không                    | M                                                    | M                                                    | M                                                    |
# | 3  |FL1803      |Tiếng Pháp PFIEV 3 |3(1-4-0-6) |Không                     | H                                                    | M                                                    | M                                                    |
# | 4  |FL1804      |Tiếng Pháp PFIEV 4 |3(1-4-0-6) |Có                        | H                                                    | M                                                    | M                                                    |
# | 5  |FL1805      |Tiếng Pháp PFIEV 5 |3(1-4-0-6) |Có                        | H                                                    | H                                                    | M                                                    |
# | 6  |FL1806      |Tiếng Pháp PFIEV 6 |3(3-1-0-6) |Có                        | H                                                    | H                                                    | M                                                    |
#
# --- Result 15 ---
# Score   : 0.6309
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Chưa đạt trình độ tiếng Nhật N3
#
# M: được miễn học (ghi điểm R)
#
# [2]: Đạt trình độ tiếng Nhật từ N3
#
# H: bắt buộc học.
#
# --- Result 16 ---
# Score   : 0.6277
# Section : ROOT
# Type    : table
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# | H ạ ngm ụ c            |Yêu cầu trình độ ngoại ngữ tối thiểu                                                                                           |
# |--------------------------|-------------------------------------------------------------------------------------------------------------------------------------------|
# |Yêu cầu đầu khóa học| +Có chứng chỉ tiếng Anh VSTEP trình độ B2 trở lên; Hoặc+ Có chứng chỉ IELTS (Academic) đạt 5.5 trở lên hoặc tương đương.|
#
# --- Result 17 ---
# Score   : 0.6277
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ DELF A1 hoặc tương đương;
#
# [2]: Đạt trình độ DELF A2 hoặc tương đương;
#
# [3]: Đạt trình độ DELF B1 hoặc tương đương.
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# (*):từ khóa K69 sẽ đổi mã và tên học phần thành: FL1801 Tiếng Pháp PFIEV 1.
#
# --- Result 18 ---
# Score   : 0.6244
# Section : ROOT
# Type    : table
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Bảng 3.1 Danh mục các học phần tiếng Anh thuộc khối ngoại ngữ cơ bản và điều kiện miễn học
#
# |TT |Mã học phần |Tên học phần  |Thời lượng |Học phần được miễn và học kỳ xếp lớp học  |Học phần được miễn và học kỳ xếp lớp học  |Học phần được miễn và học kỳ xếp lớp học  |Học phần được miễn và học kỳ xếp lớp học  |Học phần được miễn và học kỳ xếp lớp học  |Học phần được miễn và học kỳ xếp lớp học  |
# |------|-------------------|--------------------|-----------------|-----------------------------------------------------------|-----------------------------------------------------------|-----------------------------------------------------------|-----------------------------------------------------------|-----------------------------------------------------------|-----------------------------------------------------------|
# |TT |Mã học phần |Tên học phần  |Thời lượng |Nhóm 1                                                  |Nhóm 2                                                  |Nhóm 3                                                  |Nhóm 4                                                  |Nhóm 5                                                  |Nhóm 6                                                    |
# | 1  |FL1131           |Tiếng Anh cơ sở 1 |4(2-4-0-8)   |Kỳ 1                                                     | M                                                         | M                                                         | M                                                         | M                                                         | M                                                         |
# | 2  |FL1132           |Tiếng Anh cơ sở 2 |4(2-4-0-8)   |Kỳ 2                                                    |Kỳ 1                                                     | M                                                         | M                                                         | M                                                         | M                                                         |
# | 3  |FL1133           |Tiếng Anh cơ sở 3 |4(2-4-0-8)  |ĐK (Kỳ 3)                                                |Kỳ 2                                                    |Kỳ 1                                                     | M                                                         | M                                                         | M                                                         |
# | 4  |FL1134           |Tiếng Anh cơ sở 4 |4(2-4-0-8)  |ĐK (Kỳ 4)                                               |ĐK (Kỳ 4)                                                |Kỳ 2                                                    |Kỳ 1                                                     | M                                                         | M                                                         |
# | 5  |FL1135           |Tiếng Anh cơ sở 5 |4(2-4-0-8)  |ĐK (Kỳ 5)                                               |ĐK (Kỳ 5)                                               |ĐK (Kỳ 5)                                                |Kỳ 2                                                    |Kỳ 2                                                     | M                                                         |
#
# --- Result 19 ---
# Score   : 0.6212
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Sinh viên thuộc các chương trình đào tạo Elitech (bao gồm chương trình tiên tiến, chương trình đào tạo tài năng và chương trình đào tạo hợp tác quốc tế) có ngoại ngữ yêu cầu là tiếng Anh và sinh viên thuộc các chương trình đào tạo chuẩn phải có chứng chỉ tiếng Anh quốc tế 4 kỹ năng hoặc chứng chỉ VSTEP tương đương để được xét công nhận đạt chuẩn ngoại ngữ đầu ra. Các chứng chỉ tiếng Anh có giá trị công nhận trong vòng 2 năm kể từ ngày cấp.
#
# Sinh viên không đạt chuẩn ngoại ngữ quy định theo số lượng tín chỉ tích lũy sẽ bị hạn chế khối lượng tín chỉ học tập theo Quy chế đào tạo hiện hành.
#
# Điều kiện gỡ bỏ hạn chế khối lượng tín chỉ học tập được quy định cụ thể tại các phụ lục tương ứng kèm theo Quy định này.
#
# Các trường hợp ngoại lệ sẽ do Ban Đào tạo đề xuất và trình Giám đốc đại học quyết định.
#
# Quy định này được áp dụng từ năm học 2023-2024 đối với các chương trình đào tạo kể từ khóa 68 trở về sau.
#
# --- Result 20 ---
# Score   : 0.6164
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ tiếng Nhật N5 [2]: Đạt trình độ tiếng Nhật từ N4
#
# M: được miễn học (ghi điểm R); H: bắt buộc học.
#
# --- Result 21 ---
# Score   : 0.6158
# Section : ROOT
# Type    : table
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Bảng 7.3 Danh mục các học phần tiếng Nhật thuộc khối ngoại ngữ cơ bản, điều kiện miễn học và chuẩn đầu ra với chương trình Công nghệ thông tin Việt-Nhật
#
# |TT                                |Mã học phần                    |Tên học phần                    |Thời lượng                                                                                                                      |Học phần được miễn và học kỳ xếp lớp học                                                                            |Học phần được miễn và học kỳ xếp lớp học                                                                            |
# |---------------------------------------|---------------------------------------|---------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------|
# |TT                                |Mã học phần                    |Tên học phần                    |Thời lượng                                                                                                                    |Nhóm 1                                                                                                                            |Nhóm 2                                                                                                                              |
# | 1                                   |JP1110                                |Tiếng Nhật 1                    |5(0-10-0-10)                                                                                                                       |Kỳ 1                                                                                                                               | M                                                                                                                                   |
# | 2                                   |JP1120                                |Tiếng Nhật 2                    |5(0-10-0-10)                                                                                                                       |Kỳ 2                                                                                                                               | M                                                                                                                                   |
# | 3                                   |JP1132                                |Tiếng Nhật 3                    |3(0-6-0-6)                                                                                                                        |ĐK (Kỳ 3) (Miễn học nếu có chứng chỉ tiếng Nhật N3)                                                                 | M                                                                                                                                   |
# | 4                                   |JP2111                                |Tiếng Nhật 4                    |3(0-6-0-6)                                                                                                                        |ĐK (Kỳ 4) (Miễn học nếu có chứng chỉ tiếng Nhật N3)                                                                 | M                                                                                                                                   |
# |Chuẩn đầu ra khi xét tốt nghiệp| Chuẩn đầu ra khi xét tốt nghiệp| Chuẩn đầu ra khi xét tốt nghiệp| Đạt chứng chỉ tiếng Nhật từ N3 Hoặc đạt toàn bộ các học phần tiếng Nhật gồm: {JP1110, JP1120, JP1132, JP2111}| Đạt chứng chỉ tiếng Nhật từ N3 Hoặc đạt toàn bộ các học phần tiếng Nhật gồm: {JP1110, JP1120, JP1132, JP2111}| Đạt chứng chỉ tiếng Nhật từ N3 Hoặc đạt toàn bộ các học phần tiếng Nhật gồm: {JP1110, JP1120, JP1132, JP2111}|
#
# --- Result 22 ---
# Score   : 0.6151
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Nhóm 1:
#
# Không tham gia đánh giá phân loại tiếng Anh đầu vào hoặc đạt trình độ dưới Bậc 1
#
# Nhóm 2 :Đạt trình độ Bậc 1 trở lên
#
# Kỳ
#
# 1: Được xếp học ở kỳ 1
#
# Nhóm 3 :Đạt trình độ Bậc 2.1 trở lên
#
# Kỳ 2: Đượ
#
# c xếp học ở kỳ 2
#
# Nhóm 4 :Đạt trình độ Bậc 2.2 trở lên
#
# M: Được miễn học (ghi điểm R)
#
# Nhóm 5 :Đạt trình độ Bậc 2.3 trở lên
#
# Nhóm 6 :Đạt trình độ Bậc 3 trở lên
#
# ĐK: Sinh viên tự đăng ký học song hành với các học phần của CTĐT tại kỳ tương ứng (trong Bảng 3.1) nếu chưa học hoặc chưa được miễn.
#
# Bậc trình độ dựa trên quy định tại Bảng 2.1 của Phụ lục II.
#
# Đối với các chứng chỉ APTIS ESOL, Cambridge Assessment English, PEIC: Sinh viên đạt chứng chỉ A1 sẽ thuộc Nhóm 2; đạt chứng chỉ A2 sẽ thuộc Nhóm 3.
#
# --- Result 23 ---
# Score   : 0.6149
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 4.2 Yêu cầu chuẩn tiếng Anh theo số tín chỉ tích lũy và chuẩn đầu ra
#
# |Số tín chỉ tích lũy| Trình độ tiếng Anh yêu cầu                                                                         |
# |-----------------------|-------------------------------------------------------------------------------------------------------|
# |Đến 63TC           | 1) Đạt các học phần Tiếng Anh cơ sở gồm: FL1105, FL1106, FL1107, FL1108 2) Hoặc đạt tối thiểu Bậc 2.2|
# |Từ 64÷ 95 TC    |Đạt tối thiểu Bậc 2.3                                                                              |
# |Từ 96 TC         |Đạt tối thiểu Bậc 3.1                                                                              |
#
# --- Result 24 ---
# Score   : 0.6148
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Nhóm 1: Chưa đạt trình độ tiếng Nhật N3
#
# Nhóm 2: Đạt trình độ tiếng Nhật từ N3 trở lên
#
# M: Được miễn học (ghi điểm R)
#
# Kỳ 1: Được xếp học ở kỳ 1
#
# Kỳ 2: Được xếp học ở kỳ 2
#
# ĐK: Sinh viên tự đăng ký học song hành với các học phần của CTĐT tại kỳ tương ứng (trong bảng 7.3) nếu chưa học hoặc chưa được miễn.
#
# --- Result 25 ---
# Score   : 0.6147
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Thời gian tiếp nhận đơn đề nghị xét miễn học phần ngoại ngữ muộn nhất là 2 tuần trước khi bắt đầu học kỳ theo Khung kế hoạch thời gian của năm học.
#
# Yêu cầu về chuẩn ngoại ngữ theo số lượng tín chỉ tích lũy và chuẩn ngoại ngữ đầu ra được quy định cụ thể cho từng chương trình đào tạo tại các phụ lục tương ứng kèm theo Quy định này.
#
# Kết quả thi các kỳ thi ngoại ngữ nội bộ của Đại học Bách khoa Hà Nội được công nhận để xét điều kiện chuẩn ngoại ngữ theo số lượng tín chỉ tích lũy.
#
# Sinh viên được tham dự các kỳ thi tiếng Anh nội bộ của Đại học Bách khoa Hà Nội nhiều lần và được công nhận điểm thi cao nhất trong các lần thi. Kết quả thi này có giá trị công nhận trong vòng 2 năm kể từ ngày thi.
#
# --- Result 26 ---
# Score   : 0.6130
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Nhóm 1: Chưa đạt trình độ tiếng Nhật N5
#
# Nhóm 2: Đạt trình độ tiếng Nhật N5
#
# Nhóm 3
#
# :Đạt trình độ tiếng Nhật N4
#
# Nhóm 4
#
# :Đạt trình độ tiếng Nhật từ N3 trở lên
#
# M: Được miễn học (ghi điểm R)
#
# Kỳ
#
# 1: Được xếp học ở kỳ 1
#
# Kỳ 2: Được xếp học ở kỳ 2
#
# ĐK: Sinh viên tự đăng ký học song hành với các học phần của CTĐT tại kỳ tương ứng (trong Bảng 7.2) nếu chưa học hoặc chưa được miễn.
#
# --- Result 27 ---
# Score   : 0.6111
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Căn cứ phân loại trình độ ngoại ngữ đầu vào với sinh viên thuộc chương trình đào tạo có yêu cầu chuẩn đầu ra là ngoại ngữ khác tiếng Anh: dựa trên chứng chỉ quốc tế của ngôn ngữ tương ứng.
#
# Căn cứ trên kết quả phân loại trình độ ngoại ngữ đầu vào, sinh viên được xét miễn học các học phần theo quy định và được xếp lớp học ngoại ngữ tương ứng.
#
# Sinh viên không đáp ứng điều kiện phân loại trình độ ngoại ngữ theo khoản 1 hoặc khoản 2 của điều này sẽ phải học toàn bộ các học phần ngoại ngữ tương ứng với từng chương trình đào tạo theo lộ trình quy định.
#
# Tất cả các học phần ngoại ngữ tương ứng với từng chương trình đào tạo là các học phần bắt buộc. Lộ trình học tập đối với các học phần ngoại ngữ được quy định như sau:
#
# Ban Đào tạo sẽ đăng ký các học phần ngoại ngữ đối với 2 học kỳ đầu cho sinh viên dựa theo kết quả phân loại trình độ ngoại ngữ đầu vào.
#
# --- Result 28 ---
# Score   : 0.6103
# Section : ROOT
# Type    : table
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Bảng 3.2 Yêu cầu trình độ tiếng Anh theo học kỳ và chuẩn ngoại ngữ đầu ra khi xét tốt nghiệp
#
# | H ạ ngm ụ c                                                                                 |Yêu cầu                                                                                                                                    |
# |-----------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------|
# |Đăng ký học tập cho học kỳ 1                                                           |Được xếp lớp học theo quy định tại Bảng 3.1                                                                                     |
# |Đăng ký học tập cho học kỳ 2                                                           |Được xếp lớp học theo quy định tại Bảng 3.1                                                                                     |
# |Đăng ký học tập cho học kỳ 3                                                          |Sinh viên phải đăng ký học song hành học phần FL1133 Tiếng Anh cơ sở 3 nếu chưa học hoặc chưa được miễn.                    |
# |Đăng ký học tập cho học kỳ 4                                                          |Sinh viên phải đăng ký học song hành học phần FL1134 Tiếng Anh cơ sở 4 nếu chưa học hoặc chưa được miễn.                      |
# |Đăng ký học tập cho học kỳ 5                                                          |Sinh viên phải đăng ký học song hành học phần FL1135 Tiếng Anh cơ sở 5 nếu chưa học hoặc chưa được miễn.                      |
# |Chuẩn đầu ra khi xét tốt nghiệp với CTĐT chuẩn (trừ các CTĐT nhóm ngành ngôn ngữ)| Đạt chứng chỉ trình độ tối thiểu Bậc 3 (theo Bảng 2.1 của Phụ lục II)                                                     |
# |Chuẩn đầu ra khi xét tốt nghiệp với CTĐT tài năng                                |Được quy định bằng văn bản riêng, phù hợp với chuẩn đầu ra CTĐT tài năng trình độ tương ứng do Bộ Giáo dục và Đào tạo ban hành.|
#
# --- Result 29 ---
# Score   : 0.6096
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 6.2. Yêu cầu chuẩn tiếng Anh theo số tín chỉ tích lũy và chuẩn đầu ra (không áp dụng đối với chương trình hợp tác với Đại học TROY, Hoa Kỳ)
#
# |Số tín chỉ tích lũy                           |Trình độ ngoại ngữ tối thiểu                                                                                                             |
# |----------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------|
# |Từ 32 TC                                      |Yêu cầu đạt một trong các điều kiện sau: 1) IELTS 4.5 hoặc tương đương 2) Hoặc đạt tất cả các học phần có số thứ tự từ 1÷7 trong Bảng 6.1|
# |Từ 64 TC                                      |Yêu cầu đạt một trong các điều kiện sau: 1) IELTS 5.5 hoặc tương đương 2) Hoặc đạt tất cả các học phần có số thứ tự từ 1÷9 trong Bảng 6.1|
# |Điều kiện được xét nhận đồ án/khóa luận tốt nghiệp| IELTS 5.5 hoặc chứng chỉ tiếng Anh tương đương 4 kỹ năng                                                                                 |
# |Điều kiện khi xét tốt nghiệp                  |IELTS 5.5 hoặc chứng chỉ tiếng Anh tương đương 4 kỹ năng                                                                                 |
#
# --- Result 30 ---
# Score   : 0.6084
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Nhóm 1: Không có chứng chỉ tiếng Đức hoặc khi trình độ GoetheZertifikat đạt dưới mức A1 hoặc tương đương
#
# Nhóm 2 :Đạt trình độ Goethe-Zertifikat A1 hoặc tương đương Nhóm 4: Đạt trình độ Goethe-Zertifikat B1 hoặc tương đương
#
# Nhóm 3: Đạt trình độ Goethe-Zertifikat A2 hoặc tương đương Nhóm 5: Đạt trình độ Goethe -Zertifikat B2 hoặc tương đương M: được miễn học (ghi điểm R); Kỳ 1: Được xếp học ở kỳ 1; Kỳ 2: Được xếp học ở kỳ 2
#
# ĐK: Sinh viên tự đăng ký học song hành với các học phần của CTĐT tại kỳ tương ứng (trong Bảng 6.1) nếu chưa học hoặc chưa được miễn.
#
# (*)Học phần QT1524 Tiếng Đức 5 :chỉ dành cho các sinh viên học chuyển tiếp sang Đức theo chương trình Kỹ thuật Điện tử -Viễn thông, hợp tác với ĐH Leibniz Hannover.
#
# --- Result 31 ---
# Score   : 0.6076
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 3.2 Yêu cầu chuẩn tiếng Anh theo số tín chỉ tích lũy và chuẩn đầu ra
#
# |Số tín chỉ tích lũy| Trình độ tiếng Anh yêu cầu                                                                  |
# |-----------------------|------------------------------------------------------------------------------------------------|
# |Đến 63TC          |+Đạt tất cả học phần Tiếng Anh cơ sở gồm: FL1131, FL1132, FL1133+ Hoặc đạt tối thiểu Bậc 2.1|
#
# --- Result 32 ---
# Score   : 0.6074
# Section : ROOT
# Type    : section
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# 4 .Sinh viên không được phép hủy các học phần NNCB đã đăng ký học song hành, trừ trường hợp xin rút hoặc chủ động rút toàn bộ đăng ký học tập trong học kỳ.
#
# Yêu cầu về chuẩn ngoại ngữ đầu ra được quy định cụ thể cho từng CTĐT tại các Phụ lục tương ứng kèm theo Quy định này.
#
# Chứng chỉ tiếng Anh phải đánh giá đầy đủ 4 kỹ năng nghe, nói, đọc, viết; đồng thời phải được cấp trong vòng 2 năm tính đến thời điểm xét chuẩn ngoại ngữ đầu ra và còn hiệu lực tại thời điểm xét.
#
# Các trường hợp ngoại lệ sẽ do Ban Đào tạo đề xuất Giám đốc Đại học Bách khoa Hà Nội xem xét quyết định.
#
# Quy định này được áp dụng từ học kỳ 1 năm học 20252026 đối với sinh viên đại học hình thức chính quy và các CTĐT kể từ khóa 70 trở về sau, trừ các quy định sau:
#
# --- Result 33 ---
# Score   : 0.6055
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 6.3 Yêu cầu chuẩn tiếng Anh đối với chương trình đào tạo hợp tác với Đại học TROY, Hoa Kỳ
#
# |Số tín chỉ tích lũy| Trình độ ngoại ngữ tối thiểu                                                                                                                                                                                                    |
# |-----------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |Yêu cầu đầu khóa học| Đạt tối thiểu mức điểm của một trong các chứng chỉ sau:+ IELTS: 5.5 điểm+ TOEFL iBT: 61 điểm+ PEIC: 46 điểm+ Cambridge English Scale &Tests (KET, PET,FCE): 162 điểm Không xét các chứng chỉ khác với các chứng chỉ trên đây.|
#
# --- Result 34 ---
# Score   : 0.6015
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 9.3 Danh mục các học phần tiếng Nhật với chương trình Công nghệ thông tin ViệtNhật
#
# |TT |Mã học phần| Tên học phần         |Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn/cần học theo chứng chỉ đạt được| Học phần được miễn/cần học theo chứng chỉ đạt được| Trình độ                            |
# |------|---------------|---------------------------|--------------|---------------------------|------------------------------------------------------|------------------------------------------------------|----------------------------------------|
# |TT |Mã học phần| Tên học phần         |Thời lượng| Tính tín chỉ trong CTĐT| [1]                                                  | [2]                                                |Trình độ                            |
# | 1  |JP1110      |Tiếng Nhật 1            |5(0-10-0-10) |Không                   | H                                                    | M                                                  |Mức 1                                  |
# | 2  |JP1120      |Tiếng Nhật 2            |5(0-10-0-10) |Không                   | H                                                    | M                                                  |Mức 2                                  |
# | 3  |JP1132      |Tiếng Nhật 3            |3(0-6-0-6) |Không                     | H                                                    | M                                                  |Mức 3                                  |
# | 4  |JP2111      |Tiếng Nhật 4            |3(0-6-0-6) |Không                     | H                                                    | M                                                  |Mức 4                                  |
# | 5  |JP2126      |Tiếng Nhật 5            |2(0-4-0-4) |Có                        | H                                                    | H                                                  |Học phần bắt buộc, định hướng kỹ thuật|
# | 6  |JP2132      |Tiếng Nhật 6            |2(0-4-0-4) |Có                        | H                                                    | H                                                  |Học phần bắt buộc, định hướng kỹ thuật|
# ...
# | 3                                   |FLG1003                              |Tiếng Đức 3                       |6(5-2-0-12)                         |ĐK (Kỳ 3)                                                                                                                                                                                            |Kỳ 2                                                                                                                                                                                                  | M                                                                                                                                                                                                      | M                                                                                                                                                                                                      | M                                                                                                                                                                                                      |
# | 4                                   |FLG1004                              |Tiếng Đức 4                       |6(5-2-0-12)                         |ĐK (Kỳ 4)                                                                                                                                                                                           |ĐK (Kỳ 4)                                                                                                                                                                                            |Kỳ 1                                                                                                                                                                                                  | M                                                                                                                                                                                                      | M                                                                                                                                                                                                      |
# | 5                                   |QT1524 (*)                           |Tiếng Đức 5                       |0(5-2-0-12)                           |                                                                                                                                                                                                        |                                                                                                                                                                                                        |                                                                                                                                                                                                        | M                                                                                                                                                                                                      | M                                                                                                                                                                                                      |
# | 6                                   |QT1528 (*)                           |Tiếng Đức 6                       |0(4-4-0-12)                           |                                                                                                                                                                                                        |                                                                                                                                                                                                        |                                                                                                                                                                                                        |                                                                                                                                                                                                        | M                                                                                                                                                                                                      |
# | 7                                   |QT1529 (*)                           |Tiếng Đức 7                       |0(4-4-0-12)                           |                                                                                                                                                                                                        |                                                                                                                                                                                                        |                                                                                                                                                                                                        |                                                                                                                                                                                                        | M                                                                                                                                                                                                      |
# |Chuẩn đầu ra khi xét tốt nghiệp| Chuẩn đầu ra khi xét tốt nghiệp| Chuẩn đầu ra khi xét tốt nghiệp| Chuẩn đầu ra khi xét tốt nghiệp| Đạt chứng chỉ Goethe-Zertifikat trình độ tối thiểu B1 hoặc tương đương (theo Bảng quy đổi 6.2) Hoặc đạt toàn bộ các học phần tiếng Đức gồm: {FLG1001, FLG1002, FLG1003, FLG1004}| Đạt chứng chỉ Goethe-Zertifikat trình độ tối thiểu B1 hoặc tương đương (theo Bảng quy đổi 6.2) Hoặc đạt toàn bộ các học phần tiếng Đức gồm: {FLG1001, FLG1002, FLG1003, FLG1004}| Đạt chứng chỉ Goethe-Zertifikat trình độ tối thiểu B1 hoặc tương đương (theo Bảng quy đổi 6.2) Hoặc đạt toàn bộ các học phần tiếng Đức gồm: {FLG1001, FLG1002, FLG1003, FLG1004}| Đạt chứng chỉ Goethe-Zertifikat trình độ tối thiểu B1 hoặc tương đương (theo Bảng quy đổi 6.2) Hoặc đạt toàn bộ các học phần tiếng Đức gồm: {FLG1001, FLG1002, FLG1003, FLG1004}| Đạt chứng chỉ Goethe-Zertifikat trình độ tối thiểu B1 hoặc tương đương (theo Bảng quy đổi 6.2) Hoặc đạt toàn bộ các học phần tiếng Đức gồm: {FLG1001, FLG1002, FLG1003, FLG1004}|
#
# --- Result 37 ---
# Score   : 0.5989
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# |Số tín chỉ tích lũy                           |Trình độ ngoại ngữ                                                                                                                                                                                        |
# |----------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |Từ 32 TC                                      |Yêu cầu đạt một trong các điều kiện sau: 1) Đạt điểm IELTS 4.5 2) Đạt tất cả các học phần tiếng Anh trong Bảng 5.1:- Nhóm 1: đạt các học phần tiếng Anh từ 1÷7- Nhóm 2: đạt các học phần tiếng Anh từ 8÷14|
# |Từ 49 TC                                      |Yêu cầu đạt một trong các điều kiện sau: 1) Đạt điểm IELTS 5.5 2) Hoặc đạt tất cả các học phần tiếng Anh từ 15÷18 trong Bảng 5.1                                                                          |
# |Điều kiện được xét nhận đồ án/khóa luận tốt nghiệp| IELTS 5.5 hoặc chứng chỉ tiếng Anh tương đương 4 kỹ năng                                                                                                                                                  |
# |Điều kiện khi xét tốt nghiệp                  |IELTS 5.5 hoặc chứng chỉ tiếng Anh tương đương 4 kỹ năng                                                                                                                                                  |
#
# --- Result 38 ---
# Score   : 0.5988
# Section : ROOT
# Type    : table
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# Bảng 9.2 Danh mục các học phần tiếng Nhật với chương trình Hệ thống nhúng thông minh và IoT
#
# |TT |Mã học phần| Tên học phần| Thời lượng| Tính tín chỉ trong CTĐT| Học phần được miễn theo chứng chỉ đạt được| Học phần được miễn theo chứng chỉ đạt được| Học phần được miễn theo chứng chỉ đạt được| Trình độ                            |
# |------|---------------|----------------|--------------|---------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------|
# |TT |Mã học phần| Tên học phần| Thời lượng| Tính tín chỉ trong CTĐT| [1]                                          | [2]                                          | [3]                                        |Trình độ                            |
# | 1  |JP1111      |Tiếng Nhật 1 |4(0-8-0-8) |Không                     | M                                            | M                                            | M                                          |Mức 1                                  |
# | 2  |JP1121      |Tiếng Nhật 2 |4(0-8-0-8) |Không                     | H                                            | M                                            | M                                          |Mức 2                                  |
# | 3  |JP1134      |Tiếng Nhật 3 |4(0-8-0-8) |Không                     | H                                            | H                                            | M                                          |Mức 3                                  |
# | 4  |JP2113      |Tiếng Nhật 4 |4(0-8-0-8) |Không                     | H                                            | H                                            | M                                          |Mức 4                                  |
# | 5  |JP2123      |Tiếng Nhật 5 |4(0-8-0-8) |Có                        | H                                            | H                                            | H                                          |Học phần bắt buộc, định hướng kỹ thuật|
# | 6  |JP2124      |Tiếng Nhật 6 |4(0-8-0-8) |Có                        | H                                            | H                                            | H                                          |Học phần bắt buộc, định hướng kỹ thuật|
# | 7  |JP2125      |Tiếng Nhật 7 |3(0-6-0-6) |Có                        | H                                            | H                                            | H                                          |Học phần bắt buộc, định hướng kỹ thuật|
#
# --- Result 39 ---
# Score   : 0.5950
# Section : ROOT
# Type    : section
# Source  : QD_ngoai_ngu_tu_K68_CQ_final.pdf
# [1]: Đạt trình độ tiếng Nhật N5 [2]: Đạt trình độ tiếng Nhật N4 [3]: Đạt trình độ tiếng Nhật từ N3 M: được miễn học (ghi điểm R)  H: bắt buộc học.
#
# --- Result 40 ---
# Score   : 0.5945
# Section : ROOT
# Type    : table
# Source  : 06_%20Quy%20%C4%91%E1%BB%8Bnh%20ngo%E1%BA%A1i%20ng%E1%BB%AF%20t%E1%BB%AB%20K70_ch%C3%ADnh%20quy_final.pdf
# Bảng 5.2 Yêu cầu trình độ tiếng Pháp theo học kỳ và chuẩn ngoại ngữ đầu ra khi xét tốt nghiệp
#
# | H ạ ngm ụ c                                                                          |Yêu cầu với CTĐT Việt- Pháp PFIEV                                                                                                                                                                                                         |Yêu cầu với CTĐT CNTT Việt-Pháp                                                                                                                                                        |
# |----------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |Đăng ký học tập cho học kỳ 1                                                    |Được xếp lớp học theo quy định tại Bảng 5.1 (số học phần xếp học trong học kỳ có thể khác giữa các lớp của CTĐT Việt- Pháp PFIEV và CTĐT CNTT Việt- Pháp)                                                     |Được xếp lớp học theo quy định tại Bảng 5.1 (số học phần xếp học trong học kỳ có thể khác giữa các lớp của CTĐT Việt- Pháp PFIEV và CTĐT CNTT Việt- Pháp)|
# |Đăng ký học tập cho học kỳ 2                                                   |Sinh viên phải đăng ký học song hành học phần FL1803 Tiếng Pháp PFIEV 3 nếu chưa học hoặc chưa được miễn.                                                                                                                           |Sinh viên phải đăng ký học song hành học phần FL1803 Tiếng Pháp PFIEV 3 nếu chưa học hoặc chưa được miễn.                                                                     |
# |Đăng ký học tập cho học kỳ 4                                                   |Sinh viên phải đăng ký học song hành học phần FL1804 Tiếng Pháp PFIEV 4 nếu chưa học hoặc chưa được miễn.                                                                                                                           |Sinh viên phải đăng ký học song hành học phần FL1804 Tiếng Pháp PFIEV 4 nếu chưa học hoặc chưa được miễn.                                                                     |
# |Chuẩn đầu ra khi xét tốt nghiệp cử nhân                                     |Đạt trình độ tối thiểu DELF B1 hoặc tương đương theo Bảng 5.3                                                                                                                                                                             |Đạt trình độ tối thiểu DELF B1 hoặc tương đương theo Bảng 5.3                                                                                                                      |
# |Chuẩn đầu ra khi xét tốt nghiệp kỹ sư chuyên sâu                            |Đạt trình độ tối thiểu DELF B2 (hoặc tương đương theo Bảng 5.3) hoặc Chứng chỉ tiếng Anh đạt trình độ tối thiểu từ Bậc 4 (theo Phụ lục II)                                                                             |Không có                                                                                                                                                                                  |
# |Điều kiện ngoại ngữ để đăng ký nhận Phụ lục văn bằng kỹ sư của phía Pháp.| Đạt trình độ tối thiểu DELF B1 (hoặc tương đương theo Bảng 5.3) và Chứng chỉ TOEIC quốc tế với tổng hai kỹ năng Nghe &Đọc đạt từ 600 điể mtr ở lên (hoặc chứng chỉ tiếng Anh tương đương theo quy định của phía Pháp).| Không có                                                                                                                                                                                  |

# %%
from google.colab import runtime
runtime.unassign()
